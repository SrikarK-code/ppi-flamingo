# %% [markdown]
# ### **Make a new dataset**
# - target seq
# - binder seq
# - motif seq
# - cluster

# %%
from transformers import T5Tokenizer, T5EncoderModel
import torch
import re
# !pip install sentencepiece
import sentencepiece
import torch
from torch import nn
from transformers import T5ForConditionalGeneration, T5Tokenizer
from torch.utils.data import DataLoader, Dataset
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 6.9 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
import os
os.chdir('/content/drive/MyDrive/Programmable Biology Group/Srikar/Code/proteins/flamingo-ppi-gen/data_dump/per-residue-dataset')

# %%
import pandas as pd
import re

def preprocess_snp_data(file_path):
    # Read the dataset
    snp_df = pd.read_csv(file_path)

    # Function to transform energy scores
    def transform_energy_scores(energy_scores):
        transformed_scores = []
        for score in energy_scores:
            # Replace sequences of spaces/newlines with a comma
            score = re.sub(r'[\s\n]+', ',', score)
            # Remove a comma after an opening square bracket
            score = re.sub(r'\[\s*,', '[', score)
            # Remove leading commas/whitespace
            score = re.sub(r'^[\s,]+', '', score)
            transformed_scores.append(score)
        return transformed_scores

    # Apply transformations
    snp_df['energy_scores'] = transform_energy_scores(snp_df['energy_scores'])
    snp_df['energy_scores_lengths'] = snp_df['energy_scores'].apply(
        lambda x: x.count(',') + 1 - (1 if x.startswith(',') else 0)
    )

    # Calculate lengths for other columns
    snp_df['peptide_source_RCSB_lengths'] = snp_df['peptide_source_RCSB'].apply(len)
    snp_df['protein_RCSB_lengths'] = snp_df['protein_RCSB'].apply(len)
    snp_df['protein_derived_seq_length'] = snp_df['protein_derived_sequence'].apply(len)
    snp_df['peptide_derived_seq_length'] = snp_df['peptide_derived_sequence'].apply(len)

    # Calculate matching lengths count (optional, depending on your needs)
    snp_df['matching_lengths_count'] = (snp_df['energy_scores_lengths'] == snp_df['peptide_derived_seq_length']).sum()

    return snp_df

# Applying the preprocessing pipeline to each dataset
test_snp = preprocess_snp_data('testing_dataset.csv')
train_snp = preprocess_snp_data('training_dataset.csv')
val_snp = preprocess_snp_data('validation_dataset.csv')

# %%
unique_seqs = pd.concat([train_snp['peptide_derived_sequence'], train_snp['protein_derived_sequence'],
                         test_snp['peptide_derived_sequence'], test_snp['protein_derived_sequence'],
                         val_snp['peptide_derived_sequence'], val_snp['protein_derived_sequence']]).unique()

# %%
max_length = max(len(seq) for seq in unique_seqs)
print(max_length)
# Out:
# 984

# %%
import torch
import re
import pickle
from torch.utils.data import Dataset
from torch.nn.functional import pad

class ProteinInteractionDataset(Dataset):
    def __init__(self, dataframe):
        # self.protT5_model = T5ForConditionalGeneration.from_pretrained("Rostlab/prot_t5_xl_bfd")
        # self.protT5_tokenizer = T5Tokenizer.from_pretrained("Rostlab/prot_t5_xl_bfd")
        self.dataframe = dataframe

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        peptide_seq = self.dataframe.iloc[idx]['peptide_derived_sequence']
        protein_seq = self.dataframe.iloc[idx]['protein_derived_sequence']
        energy_scores = self.dataframe.iloc[idx]['energy_scores']

        max_length = 984

        # Process the energy_scores
        energy_scores = re.findall(r'-?\d+\.?\d*(?:e[-+]?\d+)?', energy_scores)
        energy_scores = [float(score) for score in energy_scores]
        energy_scores = one_hot_encode_energy_scores(energy_scores)
        # energy_scores_padded = pad(torch.tensor(energy_scores), (0, max_length - len(energy_scores)), "constant", 0)

        return torch.tensor(energy_scores), peptide_seq, protein_seq

def one_hot_encode_energy_scores(scores):
        # Assuming 'scores' is a list of energy score values
        return [1 if score <= -1 else 0 for score in scores]

# %%
# Create datasets with tokenizer
train_dataset = ProteinInteractionDataset(train_snp)
test_dataset = ProteinInteractionDataset(test_snp)
val_dataset = ProteinInteractionDataset(val_snp)

# %%
from torch.utils.data import DataLoader

train_batch_size = 1
test_batch_size = 1
val_batch_size = 1

# Create the DataLoaders
train_dataloader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=test_batch_size)
val_dataloader = DataLoader(val_dataset, batch_size=val_batch_size)

# %% [markdown]
# ### **Background Functions**

# %% [markdown]
# General

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset
import torch.optim as optim
import torch.nn.functional as F
# from transformers import RobertaModel  # Assuming use of Hugging Face's transformer models

# Helper Functions
def exists(val):
    return val is not None

def set_module_requires_grad_(module, requires_grad):
    for param in module.parameters():
        param.requires_grad = requires_grad

def freeze_model_and_make_eval_(model):
    model.eval()
    set_module_requires_grad_(model, False)

# LayerNorm class
class LayerNorm(nn.Module):
    def __init__(self, features, eps=1e-6):
        super().__init__()
        self.gain = nn.Parameter(torch.ones(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.gain * (x - mean) / (std + self.eps)

# Residual class
class Residual(nn.Module):
    def __init__(self, fn):
        super().__init__()
        self.fn = fn

    def forward(self, x, *args, **kwargs):
        return self.fn(x, *args, **kwargs) + x

# SwiGLU activation function
class SwiGLU(nn.Module):
    def forward(self, x):
        return F.silu(x[..., :x.shape[-1] // 2]) * x[..., x.shape[-1] // 2:]


class LayerNorm(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.norm = nn.LayerNorm(dim)

    def forward(self, x):
        return self.norm(x)

class SwiGLU(nn.Module):
    def forward(self, x):
        x, gate = x.chunk(2, dim=-1)
        return F.silu(gate) * x

# %% [markdown]
# Main Perciever+Cross Attn

# %%
# !pip install einops
# !pip install einops-exts
# Out:
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 798.2 kB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.7.0
# Collecting einops-exts
#   Downloading einops_exts-0.0.4-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: einops>=0.4 in /usr/local/lib/python3.10/dist-packages (from einops-exts) (0.7.0)
# Installing collected packages: einops-exts
# Successfully installed einops-exts-0.0.4

# %%
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'max_split_size_mb:4096'

import torch
from torch import nn, einsum
import torch.nn.functional as F

from einops import rearrange, repeat
from einops_exts import rearrange_many, repeat_many

def exists(val):
    return val is not None

def FeedForward(dim, mult = 4):
    inner_dim = int(dim * mult)
    return nn.Sequential(
        nn.LayerNorm(dim),
        nn.Linear(dim, inner_dim, bias = False),
        nn.GELU(),
        nn.Linear(inner_dim, dim, bias = False)
    )

class PerceiverAttention(nn.Module):
    def __init__(self, *, dim, concatenated_dim, dim_head=64, heads=8):
        super().__init__()
        self.scale = dim_head ** -0.5
        self.heads = heads
        inner_dim = dim_head * heads

        self.norm_media = nn.LayerNorm(dim)
        self.norm_latents = nn.LayerNorm(dim)
        self.to_q = nn.Linear(dim, inner_dim, bias=False)
        self.to_kv = nn.Linear(dim, inner_dim * 2, bias=False)
        self.to_out = nn.Linear(inner_dim, dim, bias=False)


    def forward(self, x, latents):
        x = self.norm_media(x)
        latents = self.norm_latents(latents)

        # print('x shape perciever attn:', x.shape)
        # print('latents shape perceiver attn', latents.shape)

        q = self.to_q(latents)
        # print('q shape:',q.shape)

        q = rearrange(q, 'b n (h d) -> b h n d', h=self.heads)
        q = q * self.scale


        kv_input = torch.cat((x, latents), dim=1)
        k, v = self.to_kv(kv_input).chunk(2, dim=-1)

        # print('k shape:',k.shape)
        # print('v shape:',v.shape)
        k = rearrange(k, 'b n (h d) -> b h n d', h=self.heads)
        v = rearrange(v, 'b n (h d) -> b h n d', h=self.heads)

        # print('rearrangement in perceiver cross attn complete...')
        # print('q shape:',q.shape)
        # print('k shape:',k.shape)
        # print('v shape:',v.shape)

        sim = einsum('... i d, ... j d -> ... i j', q, k)
        attn = sim.softmax(dim=-1)
        out = einsum('... i j, ... j d -> ... i d', attn, v)
        out = rearrange(out, 'b h n d -> b n (h d)')

        return self.to_out(out)

class PerceiverResampler(nn.Module):
    def __init__(self, *, dim, depth, dim_head=64, heads=8, num_latents=64, concatenated_dim=1536):
        super().__init__()
        self.latents = nn.Parameter(torch.randn(num_latents, dim))
        self.layers = nn.ModuleList([])

        for _ in range(depth):
            self.layers.append(nn.ModuleList([
                PerceiverAttention(dim=dim, concatenated_dim=concatenated_dim, dim_head=dim_head, heads=heads),
                FeedForward(dim=dim)
            ]))

    def forward(self, x):
        latents = repeat(self.latents, 'n d -> b n d', b=x.shape[0])

        for attn, ff in self.layers:
            latents = attn(x, latents) + latents
            latents = ff(latents) + latents

        return latents

class MaskedCrossAttention(nn.Module):
    def __init__(self, *, dim, concatenated_dim=1536, dim_head=64, heads=8, only_attend_immediate_media=True):
        super().__init__()
        self.scale = dim_head ** -0.5
        self.heads = heads
        inner_dim = dim_head * heads

        self.norm = nn.LayerNorm(dim)
        self.to_q = nn.Linear(dim, inner_dim, bias=False)
        self.to_kv = nn.Linear(dim, inner_dim * 2, bias=False)
        self.to_out = nn.Linear(inner_dim, dim, bias=False)
        self.only_attend_immediate_media = only_attend_immediate_media

    def forward(self, x, media, media_locations=None):
        b, t, _ = x.shape
        _, m, _ = media.shape
        h = self.heads

        x = self.norm(x)
        q = self.to_q(x)
        q = rearrange(q, 'b n (h d) -> b h n d', h=h)

        # No need to reshape media as it's already 3D
        k, v = self.to_kv(media).chunk(2, dim=-1)
        k = rearrange(k, 'b n (h d) -> b h n d', h=h)
        v = rearrange(v, 'b n (h d) -> b h n d', h=h)

        q = q * self.scale
        sim = einsum('... i d, ... j d -> ... i j', q, k)

        if media_locations is not None:
            mask = media_locations.unsqueeze(1).unsqueeze(2)
            mask = rearrange(mask, 'b n -> b 1 n 1')
            sim = sim.masked_fill(mask == 0, float('-inf'))

        sim = sim - sim.amax(dim=-1, keepdim=True).detach()
        attn = sim.softmax(dim=-1)
        out = einsum('... i j, ... j d -> ... i d', attn, v)
        out = rearrange(out, 'b h n d -> b n (h d)', h=self.heads)

        return self.to_out(out)


class GatedCrossAttentionBlock(nn.Module):
    def __init__(self, *, dim, dim_head=64, heads=8, ff_mult=4, only_attend_immediate_media=True):
        super().__init__()
        self.attn = MaskedCrossAttention(dim=dim, concatenated_dim=1536, dim_head=dim_head, heads=heads, only_attend_immediate_media=only_attend_immediate_media)
        self.attn_gate = nn.Parameter(torch.tensor([0.]))
        self.ff = FeedForward(dim, mult=ff_mult)
        self.ff_gate = nn.Parameter(torch.tensor([0.]))

    def forward(self, x, media, media_locations=None):
        gate = self.attn_gate.tanh()
        x = self.attn(x, media, media_locations=media_locations) * gate + x
        x = self.ff(x) * self.ff_gate.tanh() + x
        return x

# %% [markdown]
# ### **ProtFlamingo**

# %%
from transformers import GPT2Tokenizer

# Load the tokenizer for the ProtGPT2 model from Hugging Face
tokenizer = GPT2Tokenizer.from_pretrained('nferruz/ProtGPT2')

# Get the number of tokens in the tokenizer
num_tokens = len(tokenizer)

print(f"The ProtGPT2 model has {num_tokens} tokens in its vocabulary.")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/655k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/314k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/357 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/850 [00:00<?, ?B/s]
# The ProtGPT2 model has 50257 tokens in its vocabulary.

# %%
import torch
import torch.nn as nn
from transformers import GPT2LMHeadModel, GPT2Tokenizer

class ProtFlamingo(nn.Module):
    def __init__(self, model_path, cross_attn_every=1, dim_head=64, heads=8, motif_embedding_dim=1280, perceiver_depth=2, perceiver_num_latents=64):
        super().__init__()

        # Load ProtGPT2 model
        self.protGPT2_model = GPT2LMHeadModel.from_pretrained(model_path)
        self.protGPT2_tokenizer = GPT2Tokenizer.from_pretrained(model_path)

        # Create an embedding layer for one-hot motifs to learn positional embeddings
        self.motif_embedding = nn.Embedding(num_embeddings=motif_embedding_dim, embedding_dim=self.protGPT2_model.config.n_embd)

        # Define Perceiver Resampler
        self.perceiver_resampler = PerceiverResampler(dim=self.protGPT2_model.config.n_embd, depth=perceiver_depth, dim_head=dim_head, heads=heads, num_latents=perceiver_num_latents)

        # Access the decoder blocks from ProtGPT2 model
        self.decoder_blocks = self.protGPT2_model.transformer.h

        # Intersperse GatedCrossAttentionBlocks within the GPT2 decoder blocks
        self.layers = nn.ModuleList([])
        for i, block in enumerate(self.decoder_blocks):
            self.layers.append(block)
            if i % cross_attn_every == 0 and i != 0:
                self.layers.append(GatedCrossAttentionBlock(dim=self.protGPT2_model.config.n_embd, dim_head=dim_head, heads=heads))

    def forward(self, target_seqs, one_hot_motifs):
        # Tokenize target sequences
        inputs = self.protGPT2_tokenizer(target_seqs, return_tensors="pt")
        input_ids = inputs['input_ids'].to(device)
        attention_mask = inputs['attention_mask'].to(device)

        # Obtain embeddings from GPT2
        embeddings = self.protGPT2_model.transformer.wte(input_ids)
        # print('embeddings shape')
        # print(embeddings.shape)

        # Convert one-hot motifs to learned positional embeddings
        one_hot_motif_embeddings = self.motif_embedding(one_hot_motifs)
        # print('one hot motif shape')
        # print(one_hot_motif_embeddings.shape)

        # Process through Perceiver Resampler
        processed_motif_embeddings = self.perceiver_resampler(one_hot_motif_embeddings)
        # print(processed_motif_embeddings.shape)

        # Pass through layers (GPT2 Blocks and GatedCrossAttentionBlocks)
        for layer in self.layers:
            # print(layer)
            if isinstance(layer, GatedCrossAttentionBlock):
                embeddings = layer(embeddings, processed_motif_embeddings)
            else:
                layer_outputs = layer(embeddings, attention_mask=attention_mask)
                embeddings = layer_outputs[0]

        # Final logits

        logits = self.protGPT2_model.lm_head(embeddings)
        # print(logits)
        # print(logits.shape)
        #print(self.protGPT2_model)
        return logits

# %% [markdown]
# ### **Initialize Model**

# %%
# Parameters for initializing the model
cross_attn_every = 3  # Intersperse a GatedCrossAttentionBlock after every 3 GPT2 blocks
dim_head = 64         # Dimension of each head in multi-head attention
heads = 8             # Number of heads in multi-head attention
perceiver_num_latents = 64  # Number of latents in PerceiverResampler
perceiver_depth = 2        # Depth of the PerceiverResampler

# Initialize the ProtFlamingo model
model = ProtFlamingo(model_path='nferruz/ProtGPT2',
                             cross_attn_every=cross_attn_every,
                             dim_head=dim_head,
                             heads=heads,
                             perceiver_num_latents=perceiver_num_latents,
                             perceiver_depth=perceiver_depth)

# If using a GPU, move the model to GPU
if torch.cuda.is_available():
    model = model.cuda()

import torch

def init_weights(m):
    if type(m) == torch.nn.Linear:
        torch.nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

model.apply(init_weights)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
# Out:
# pytorch_model.bin:   0%|          | 0.00/3.13G [00:00<?, ?B/s]

# %%
tokenizer
# Out:
# GPT2Tokenizer(name_or_path='nferruz/ProtGPT2', vocab_size=50257, model_max_length=1000000000000000019884624838656, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<|endoftext|>', 'eos_token': '<|endoftext|>', 'unk_token': '<|endoftext|>'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# }

# %% [markdown]
# ### **Train Loop**

# %%
import torch
import torch.nn as nn

def train_epoch(model, data_loader, optimizer, device, clip_value=1.0):
    model.train()
    total_loss = 0
    total_batches = 0

    for batch in data_loader:
        one_hot_motifs, target_seqs_tuple, binder_seqs_tuple = batch
        target_seqs = target_seqs_tuple[0]
        binder_seqs = binder_seqs_tuple[0]

        # print(target_seqs)
        # print(len(target_seqs))
        # print(binder_seqs)
        # print(len(binder_seqs))

        # Custom character-level tokenization
        binder_inputs = tokenizer(target_seqs, return_tensors="pt")
        binder_input_ids = binder_inputs['input_ids'].to(device)
        binder_attention_mask = binder_inputs['attention_mask'].to(device)

        # Move data to the device
        binder_input_ids = binder_input_ids.to(device)
        # print(binder_input_ids)
        # print(len(binder_input_ids))

        one_hot_motifs = one_hot_motifs.to(device)
        # print(one_hot_motifs)
        # print(len(one_hot_motifs))

        optimizer.zero_grad()

        # Forward pass
        outputs = model(target_seqs, one_hot_motifs)

        # Loss calculation
        # print("_______________________")
        # print('INPUTS FOR LOSS CALCULATIONS')
        # print(outputs.shape)
        # print(binder_input_ids.shape)


        # print('ce loss calc begins...')
        # print('outputs shape:',outputs.view(-1, outputs.size(-1)).shape) #984,128
        # print('binder input ids shape:',binder_input_ids.view(-1).shape) #984
        # loss = nn.CrossEntropyLoss()(logits,targets)
        loss = nn.CrossEntropyLoss()(outputs.view(-1, outputs.size(-1)), binder_input_ids.view(-1))
        total_loss += loss.item()
        print(loss)

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)
        optimizer.step()

        total_batches += 1

    average_loss = total_loss / total_batches
    print(average_loss)
    return average_loss

# Example usage
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

num_epochs = 5
for epoch in range(num_epochs):
    train_loss = train_epoch(model, train_dataloader, optimizer, device)
    print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {train_loss:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# tensor(19.5016, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.7615, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(14.0471, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.6839, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.4813, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.5723, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9544, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.0467, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(13.6778, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1302, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(13.5293, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7342, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5984, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1554, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(12.6440, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1165, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0942, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2557, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4736, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3994, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3395, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(15.6031, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3380, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.8857, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(23.8045, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.1059, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.4649, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8357, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5262, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7364, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(13.5321, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(25.3290, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6526, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2622, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.1408, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.3044, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.1819, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.0020, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(13.0766, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0440, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9726, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5462, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2226, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2332, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1107, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7647, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.9289, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5170, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(21.8461, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(30.5689, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1106, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7679, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(12.2535, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.2690, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.3130, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0593, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4815, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.5282, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3617, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9013, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2394, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.3584, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3264, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8512, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0030, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.3338, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(19.8387, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2127, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5032, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7326, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.7166, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2638, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2679, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(31.9767, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(23.7493, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0164, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.3264, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7000, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3725, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.7001, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7450, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.3387, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.2577, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.7718, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.9500, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1602, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.4055, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5897, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(13.9606, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.0784, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.5375, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4459, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9852, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9062, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3700, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.9560, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.5894, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2140, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4821, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(14.8263, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0765, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2496, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.9910, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1486, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.3609, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4191, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(25.3140, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.6003, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(13.6647, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.5801, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1443, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9096, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9875, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3946, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.4801, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.3698, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.0574, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4421, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.5188, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7063, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(12.5687, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.3664, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2553, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.7537, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9663, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(33.8457, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.2343, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4101, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.1354, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.7529, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3508, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3785, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.8708, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3014, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.3784, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6920, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(19.7433, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(16.5970, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(20.7713, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(16.7813, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9684, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.5259, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8046, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9443, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(17.1281, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7608, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3388, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.6629, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.4211, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3078, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.8145, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.3147, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(15.8967, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1866, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6153, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.8771, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6397, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7431, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3001, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8409, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.6411, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5773, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6183, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8838, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6434, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5611, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1041, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.3848, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6174, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(20.9985, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.8870, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8802, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7204, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4923, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(12.1813, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5344, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.8425, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.5661, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4753, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7862, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(12.2626, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9779, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(21.5143, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.1517, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8418, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2381, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6453, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(27.9098, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(19.7245, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8541, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8061, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(17.5518, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.6310, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.0837, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4697, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.1350, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7705, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7301, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.9245, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.0933, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(21.3311, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9925, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4573, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(23.6904, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3899, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4024, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.8275, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(30.8361, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(26.1261, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4557, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4021, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(17.2757, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.1414, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(12.3939, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.0006, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0363, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.9862, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1564, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0173, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0302, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.7501, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(43.1329, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5698, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1115e-06, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.1623, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1737, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0914, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(13.0718, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(22.2363, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4320, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6181, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(18.9116, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8141, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0494, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(23.6754, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.4768, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9708, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0964, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4387e-09, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(12.2620, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2899, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1742, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4444, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(12.2740, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.4140, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(12.0113, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(15.1618, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.3758, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1154, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3605, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2744, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.9453, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(58.6516, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.9294, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5441, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2549, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2786, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1682, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(19.9392, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3545, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.7781, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(13.1671, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1028, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2142, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1423, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2230, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2825, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9175, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.7605, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6716, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(17.0892, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.6867, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7549, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(17.8079, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6668, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8346, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.8380, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(17.7124, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4350, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5608e-05, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0822, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.3291, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.6238, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.8468, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4783, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.1237, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.4653, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2363, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2547, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5714, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4881, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9048, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8689, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.4179, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(14.7687, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1477, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.7433, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.2307, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.1352, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(19.2641, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6557, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1206, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.1484, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6884, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9744, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2790, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(19.6675, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4164, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(27.7403, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.7749, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8621, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6860, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.0056, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2930, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.1139, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7553, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8530, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(17.8062, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.7633, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9366, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2743e-05, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0169, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6635, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4155, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2781, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9822, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9970, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.3829, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(76.7496, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6321, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2942, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1535, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.5196, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.5855, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0428, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(28.1459, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6968, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(22.6103, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0595, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5354, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(14.4036, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.8507, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1996, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4516, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0358, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6928, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(16.3388, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6348, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.4259, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.2694, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7706, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(18.9450, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.8209, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.7927, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(32.5249, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(16.6715, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5712, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7906, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8937, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3085, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2356, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1993, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(14.0147, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2615, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7088, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2343, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3637, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.9701, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8401, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(21.5164, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1762, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(26.3395, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(15.2017, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.5482, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(32.2662, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1564, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9981, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(18.5278, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1002, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4189, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9573, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.6412, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.8121, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5717, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(27.3329, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.5487, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4292, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.6162, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3317, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8342, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5885, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.5771, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4316, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6649, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.4494, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6212, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.2023, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.4299, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(17.6559, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4959, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4330, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.2705, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5324, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.0417, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4756, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(24.9104, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(29.8148, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(24.0352, device='cuda:0', grad_fn=<NllLossBackward0>)
# ...
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.1230, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(16.1689, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(41.6193, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.7286, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8741, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(47.9823, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6781, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9344, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.4950, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7243, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(35.1088, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0003, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.8911, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4363, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8310, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.2134, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(89.4353, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(17.8057, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(20.7559, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6345, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8024, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(15.5243, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5819, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(30.0845, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(14.0818, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.8422, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(53.7745, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(13.7136, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.7697, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(21.1488, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.6036, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4597, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(20.9547, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(19.2128, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(16.8542, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9596, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(15.1232, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.0901, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.9950, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.2509, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.5071, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7191, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6790, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(13.0961, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.3256, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.8645, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7562, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9574, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.7090, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7627, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(19.7791, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(17.4767, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.4966, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.8909, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9822, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4565, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.1683, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0070e-09, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8952, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.7150, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5316, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(13.3297, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(20.9702, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.6890, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(18.2341, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(36.8879, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.1396, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.8510, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.5786, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(30.9918, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(33.4889, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.9326, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(29.1248, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(25.1433, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.4683, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7874, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.5989, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9056, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6896, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(20.9237, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.3200, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(38.3959, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(45.0441, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.2628, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0551, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0484, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.3804, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.6640, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9389, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(28.9193, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(15.2425, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(12.9172, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.6749, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.4237, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.3192, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(44.6829, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.5743, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(30.1695, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6337, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(16.5321, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.6000, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(34.3009, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.1146, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(47.6362, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0488, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(20.2532, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7590, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(21.2914, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(40.5090, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.5049, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3108, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7332, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(28.4371, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.1982, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(17.8094, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(40.2870, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(26.9124, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(21.5640, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.3169, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(26.7884, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(14.9675, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0575, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5654, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(12.0226, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(15.1901, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(22.5169, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(16.4629, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.5665, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.9405, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5762, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(21.0263, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.0180, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.4460, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(23.8648, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(24.7820, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(21.8732, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.3075, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.4810, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(11.0445, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(7.3486, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(14.7923, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(8.5265, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(10.7662, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(6.0687, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.1622, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(9.0187, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7213, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(5.4870, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0., device='cuda:0', grad_fn=<NllLossBackward0>)
# 6.051890324297871
# Epoch 5/5, Training Loss: 6.0519

# %%
epoch
# Out:
# 4

# %%
# save model
torch.save(model.state_dict(), '/content/drive/MyDrive/Programmable Biology Group/Srikar/Code/proteins/flamingo-ppi-gen/flamingo-gpt2-v1.pth')

# %%
train_loss
# Out:
# 6.051890324297871
